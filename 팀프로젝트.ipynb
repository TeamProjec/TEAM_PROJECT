# %% [markdown]
# 연습데이터 전처리 및 자연어처리 연습.

# %%
import pandas as pd

# %%
movie_2017 = pd.read_csv('C:/Users/USER/Downloads/2017_01_movie.csv', header=3, thousands=',' , encoding='euc-kr')
movie_2017
movie_2017.drop([0], inplace=True)
movie_2017.rename(columns={movie_2017.columns[4] : "매출액점유율"}, inplace=True)
movie_2017.head()
# Out:
#   순위      영화명         개봉일          매출액   매출액점유율        누적매출액        관객수   \
# 1  1       공조  2017-01-18  3.986355e+10  21.10%  3.986355e+10  4860116.0
# 2  2      더 킹  2017-01-18  3.621918e+10  19.20%  3.621918e+10  4410440.0
# 3  3  너의 이름은.  2017-01-04  2.751144e+10  14.60%  2.782663e+10  3417819.0
# 4  4      마스터  2016-12-21  1.825639e+10   9.70%  5.804103e+10  2210450.0
# 5  5      모아나  2017-01-12  1.513690e+10   8.00%  1.513690e+10  1933044.0
#
#       누적관객수    스크린수     상영횟수  대표국적  국적                  배급사
# 1  4860116.0  1392.0  66643.0    한국  한국            씨제이이앤엠(주)
# 2  4410440.0  1310.0  72859.0    한국  한국  (주)넥스트엔터테인먼트월드(NEW)
# 3  3454582.0   947.0  71919.0    일본  일본        메가박스중앙(주)플러스엠
# 4  7145770.0  1245.0  55943.0    한국  한국            씨제이이앤엠(주)
# 5  1933044.0   953.0  41025.0    미국  미국   월트디즈니컴퍼니코리아 유한책임회사

# %%
movie_2017.rename(columns={movie_2017.columns[0] : "순위",
                           movie_2017.columns[1] : "영화명",
                           movie_2017.columns[2] : "개봉일",
                           movie_2017.columns[3] : "매출액",
                           movie_2017.columns[4] : "매출액점유율",
                           movie_2017.columns[5] : "누적매출액",
                           movie_2017.columns[6] : "관객수",
                           movie_2017.columns[7] : "누적관객수",
                           movie_2017.columns[8] : "스크린수",
                           movie_2017.columns[9] : "상영횟수",
                           movie_2017.columns[10] : "대표국적",
                           movie_2017.columns[11] : "국적",
                           movie_2017.columns[12] : "배급사"}, inplace=True)
movie_2017.head()
# Out:
#                 순위  영화명         개봉일          매출액  매출액점유율        누적매출액  \
# 0              NaN  NaN         NaN          NaN     NaN          NaN
# 1  월별 박스오피스 검색 리스트  NaN         NaN          NaN     NaN          NaN
# 2               순위  영화명         개봉일         매출액      매출액       누적매출액
# 3              NaN  NaN         NaN          NaN    점유율           NaN
# 4                1   공조  2017-01-18  39863545569  21.10%  39863545569
#
#        관객수    누적관객수   스크린수   상영횟수   대표국적   국적        배급사
# 0      NaN      NaN    NaN    NaN    NaN  NaN        NaN
# 1      NaN      NaN    NaN    NaN    NaN  NaN        NaN
# 2     관객수    누적관객수   스크린수   상영횟수   대표국적   국적        배급사
# 3      NaN      NaN    NaN    NaN    NaN  NaN        NaN
# 4  4860116  4860116   1392  66643     한국   한국  씨제이이앤엠(주)

# %%
movie_2017.drop([0], inplace=True)
movie_2017.head()
# Out:
#   순위      영화명         개봉일          매출액      매출액        누적매출액        관객수   \
# 1  1       공조  2017-01-18  3.986355e+10  21.10%  3.986355e+10  4860116.0
# 2  2      더 킹  2017-01-18  3.621918e+10  19.20%  3.621918e+10  4410440.0
# 3  3  너의 이름은.  2017-01-04  2.751144e+10  14.60%  2.782663e+10  3417819.0
# 4  4      마스터  2016-12-21  1.825639e+10   9.70%  5.804103e+10  2210450.0
# 5  5      모아나  2017-01-12  1.513690e+10   8.00%  1.513690e+10  1933044.0
#
#       누적관객수    스크린수     상영횟수  대표국적  국적                  배급사
# 1  4860116.0  1392.0  66643.0    한국  한국            씨제이이앤엠(주)
# 2  4410440.0  1310.0  72859.0    한국  한국  (주)넥스트엔터테인먼트월드(NEW)
# 3  3454582.0   947.0  71919.0    일본  일본        메가박스중앙(주)플러스엠
# 4  7145770.0  1245.0  55943.0    한국  한국            씨제이이앤엠(주)
# 5  1933044.0   953.0  41025.0    미국  미국   월트디즈니컴퍼니코리아 유한책임회사

# %%
movie_2017.drop([1], inplace=True)
movie_2017.head()
# Out:
#     순위      영화명         개봉일          매출액  매출액점유율        누적매출액      관객수  \
# 2   순위      영화명         개봉일         매출액      매출액       누적매출액      관객수
# 3  NaN      NaN         NaN          NaN    점유율           NaN      NaN
# 4    1       공조  2017-01-18  39863545569  21.10%  39863545569  4860116
# 5    2      더 킹  2017-01-18  36219182509  19.20%  36219182509  4410440
# 6    3  너의 이름은.  2017-01-04  27511443256  14.60%  27826630256  3417819
#
#      누적관객수   스크린수   상영횟수   대표국적   국적                  배급사
# 2   누적관객수   스크린수   상영횟수   대표국적   국적                  배급사
# 3      NaN    NaN    NaN    NaN  NaN                  NaN
# 4  4860116   1392  66643     한국   한국            씨제이이앤엠(주)
# 5  4410440   1310  72859     한국   한국  (주)넥스트엔터테인먼트월드(NEW)
# 6  3454582    947  71919     일본   일본        메가박스중앙(주)플러스엠

# %%
movie_2017.drop([2], inplace=True)
movie_2017.head()
# Out:
#     순위      영화명         개봉일          매출액  매출액점유율        누적매출액      관객수  \
# 3  NaN      NaN         NaN          NaN    점유율           NaN      NaN
# 4    1       공조  2017-01-18  39863545569  21.10%  39863545569  4860116
# 5    2      더 킹  2017-01-18  36219182509  19.20%  36219182509  4410440
# 6    3  너의 이름은.  2017-01-04  27511443256  14.60%  27826630256  3417819
# 7    4      마스터  2016-12-21  18256388200   9.70%  58041029265  2210450
#
#      누적관객수  스크린수   상영횟수 대표국적   국적                  배급사
# 3      NaN   NaN    NaN  NaN  NaN                  NaN
# 4  4860116  1392  66643   한국   한국            씨제이이앤엠(주)
# 5  4410440  1310  72859   한국   한국  (주)넥스트엔터테인먼트월드(NEW)
# 6  3454582   947  71919   일본   일본        메가박스중앙(주)플러스엠
# 7  7145770  1245  55943   한국   한국            씨제이이앤엠(주)

# %%
movie_2017.drop([3], inplace=True)
movie_2017.head()
# Out:
#   순위      영화명         개봉일          매출액  매출액점유율        누적매출액      관객수    누적관객수  \
# 4  1       공조  2017-01-18  39863545569  21.10%  39863545569  4860116  4860116
# 5  2      더 킹  2017-01-18  36219182509  19.20%  36219182509  4410440  4410440
# 6  3  너의 이름은.  2017-01-04  27511443256  14.60%  27826630256  3417819  3454582
# 7  4      마스터  2016-12-21  18256388200   9.70%  58041029265  2210450  7145770
# 8  5      모아나  2017-01-12  15136903907   8.00%  15136903907  1933044  1933044
#
#    스크린수   상영횟수 대표국적  국적                  배급사
# 4  1392  66643   한국  한국            씨제이이앤엠(주)
# 5  1310  72859   한국  한국  (주)넥스트엔터테인먼트월드(NEW)
# 6   947  71919   일본  일본        메가박스중앙(주)플러스엠
# 7  1245  55943   한국  한국            씨제이이앤엠(주)
# 8   953  41025   미국  미국   월트디즈니컴퍼니코리아 유한책임회사

# %%
movie_2017.rename(columns={movie_2017.columns[4] : "매출액점유율"}, inplace=True)
movie_2017.head()
# Out:
#   순위      영화명         개봉일          매출액   매출액점유율        누적매출액        관객수   \
# 1  1       공조  2017-01-18  3.986355e+10  21.10%  3.986355e+10  4860116.0
# 2  2      더 킹  2017-01-18  3.621918e+10  19.20%  3.621918e+10  4410440.0
# 3  3  너의 이름은.  2017-01-04  2.751144e+10  14.60%  2.782663e+10  3417819.0
# 4  4      마스터  2016-12-21  1.825639e+10   9.70%  5.804103e+10  2210450.0
# 5  5      모아나  2017-01-12  1.513690e+10   8.00%  1.513690e+10  1933044.0
#
#       누적관객수    스크린수     상영횟수  대표국적  국적                  배급사
# 1  4860116.0  1392.0  66643.0    한국  한국            씨제이이앤엠(주)
# 2  4410440.0  1310.0  72859.0    한국  한국  (주)넥스트엔터테인먼트월드(NEW)
# 3  3454582.0   947.0  71919.0    일본  일본        메가박스중앙(주)플러스엠
# 4  7145770.0  1245.0  55943.0    한국  한국            씨제이이앤엠(주)
# 5  1933044.0   953.0  41025.0    미국  미국   월트디즈니컴퍼니코리아 유한책임회사

# %%
movie_2017['흥행지수'] = (movie_2017['누적매출액 '] / movie_2017['누적관객수 ']) * movie_2017['상영횟수 ']
movie_2017.sort_values(by='흥행지수', ascending=False).head()
# Out:
#      순위      영화명         개봉일          매출액   매출액점유율        누적매출액         관객수   \
# 493  합계      NaN         NaN  1.890000e+11     NaN  7.450000e+11  23255258.0
# 2     2      더 킹  2017-01-18  3.621918e+10  19.20%  3.621918e+10   4410440.0
# 3     3  너의 이름은.  2017-01-04  2.751144e+10  14.60%  2.782663e+10   3417819.0
# 1     1       공조  2017-01-18  3.986355e+10  21.10%  3.986355e+10   4860116.0
# 4     4      마스터  2016-12-21  1.825639e+10   9.70%  5.804103e+10   2210450.0
#
#          누적관객수     스크린수      상영횟수  대표국적   국적                  배급사   \
# 493  92516525.0  18032.0  537877.0   NaN  NaN                  NaN
# 2     4410440.0   1310.0   72859.0    한국   한국  (주)넥스트엔터테인먼트월드(NEW)
# 3     3454582.0    947.0   71919.0    일본   일본        메가박스중앙(주)플러스엠
# 1     4860116.0   1392.0   66643.0    한국   한국            씨제이이앤엠(주)
# 4     7145770.0   1245.0   55943.0    한국   한국            씨제이이앤엠(주)
#
#              흥행지수
# 493  4.331317e+09
# 2    5.983288e+08
# 3    5.793070e+08
# 1    5.466179e+08
# ...

# %%
import pandas as pd

movie_2017 = pd.read_csv('C:/Users/USER/Downloads/2017_01_movie.csv', header=3, thousands=',' , encoding='euc-kr')
movie_2017.rename(columns={movie_2017.columns[4] : "매출액점유율"}, inplace=True)


movie_2017.drop([0], inplace=True)
movie_2017.drop([493], inplace=True)

movie_2017['흥행지수'] = (movie_2017['누적매출액 '] / movie_2017['누적관객수 ']) * movie_2017['상영횟수 ']
movie_2017.sort_values(by='흥행지수', ascending=False).head(5)
# Out:
#   순위      영화명         개봉일          매출액   매출액점유율        누적매출액        관객수   \
# 2  2      더 킹  2017-01-18  3.621918e+10  19.20%  3.621918e+10  4410440.0
# 3  3  너의 이름은.  2017-01-04  2.751144e+10  14.60%  2.782663e+10  3417819.0
# 1  1       공조  2017-01-18  3.986355e+10  21.10%  3.986355e+10  4860116.0
# 4  4      마스터  2016-12-21  1.825639e+10   9.70%  5.804103e+10  2210450.0
# 5  5      모아나  2017-01-12  1.513690e+10   8.00%  1.513690e+10  1933044.0
#
#       누적관객수    스크린수     상영횟수  대표국적  국적                  배급사           흥행지수
# 2  4410440.0  1310.0  72859.0    한국  한국  (주)넥스트엔터테인먼트월드(NEW)  5.983288e+08
# 3  3454582.0   947.0  71919.0    일본  일본        메가박스중앙(주)플러스엠  5.793070e+08
# 1  4860116.0  1392.0  66643.0    한국  한국            씨제이이앤엠(주)  5.466179e+08
# 4  7145770.0  1245.0  55943.0    한국  한국            씨제이이앤엠(주)  4.543932e+08
# 5  1933044.0   953.0  41025.0    미국  미국   월트디즈니컴퍼니코리아 유한책임회사  3.212506e+08

# %%
movie_2017.to_csv('C:/Users/USER/Downloads/2017_01_movie(1).csv', sep=',',
                  encoding='utf-8')

# %%
import numpy as np
from pandas import Series, DataFrame
movie_2017['흥행순위'] = movie_2017['흥행지수'].rank(ascending=False)

# %%
movie_2017.sort_values(by='흥행순위', ascending=True).head()
# Out:
#   순위      영화명         개봉일          매출액   매출액점유율        누적매출액        관객수   \
# 2  2      더 킹  2017-01-18  3.621918e+10  19.20%  3.621918e+10  4410440.0
# 3  3  너의 이름은.  2017-01-04  2.751144e+10  14.60%  2.782663e+10  3417819.0
# 1  1       공조  2017-01-18  3.986355e+10  21.10%  3.986355e+10  4860116.0
# 4  4      마스터  2016-12-21  1.825639e+10   9.70%  5.804103e+10  2210450.0
# 5  5      모아나  2017-01-12  1.513690e+10   8.00%  1.513690e+10  1933044.0
#
#       누적관객수    스크린수     상영횟수  대표국적  국적                  배급사           흥행지수  \
# 2  4410440.0  1310.0  72859.0    한국  한국  (주)넥스트엔터테인먼트월드(NEW)  5.983288e+08
# 3  3454582.0   947.0  71919.0    일본  일본        메가박스중앙(주)플러스엠  5.793070e+08
# 1  4860116.0  1392.0  66643.0    한국  한국            씨제이이앤엠(주)  5.466179e+08
# 4  7145770.0  1245.0  55943.0    한국  한국            씨제이이앤엠(주)  4.543932e+08
# 5  1933044.0   953.0  41025.0    미국  미국   월트디즈니컴퍼니코리아 유한책임회사  3.212506e+08
#
#    흥행순위
# 2   1.0
# 3   2.0
# 1   3.0
# 4   4.0
# 5   5.0

# %%
movie_2017.sort_values(by='흥행지수', ascending=False).head(50)
# Out:
#     순위                              영화명         개봉일          매출액   매출액점유율  \
# 2    2                              더 킹  2017-01-18  3.621918e+10  19.20%
# 3    3                          너의 이름은.  2017-01-04  2.751144e+10  14.60%
# 1    1                               공조  2017-01-18  3.986355e+10  21.10%
# 4    4                              마스터  2016-12-21  1.825639e+10   9.70%
# 5    5                              모아나  2017-01-12  1.513690e+10   8.00%
# 6    6                             라라랜드  2016-12-07  6.442465e+09   3.40%
# 8    8                             패신저스  2017-01-04  5.459487e+09   2.90%
# 10  10                             얼라이드  2017-01-11  4.189302e+09   2.20%
# 11  11                   로그 원: 스타워즈 스토리  2016-12-28  3.913015e+09   2.10%
# 14  14                          어쌔신 크리드  2017-01-11  2.894687e+09   1.50%
# 7    7                                씽  2016-12-21  5.059437e+09   2.70%
# 15  15                         사랑하기 때문에  2017-01-04  2.536446e+09   1.30%
# ...

# %%
movie_2017.to_csv('C:/Users/USER/Downloads/2017_01_movie(1.1).csv', sep=',',
                encoding='euc-kr')

# %%
### 자연어처리

# %%
#-*- coding: utf-8 -*-
def read_data(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        # txt 파일의 헤더(id document label)는 제외하기
        data = data[1:]
    return data

train_data = read_data('data/project_data/ratings_train.txt')
test_data = read_data('data/project_data/ratings_test.txt')

# %%
print(len(train_data))
print(len(train_data[0]))
print(len(test_data))
print(len(test_data[0]))
# Out:
# 150000
# 3
# 50000
# 3

# %%
from konlpy.tag import Okt

okt = Okt()
print(okt.pos(u'이 밤 그날의 반딧불을 당신의 창 가까이 보낼게요'))
# Out:
# [('이', 'Noun'), ('밤', 'Noun'), ('그날', 'Noun'), ('의', 'Josa'), ('반딧불', 'Noun'), ('을', 'Josa'), ('당신', 'Noun'), ('의', 'Josa'), ('창', 'Noun'), ('가까이', 'Noun'), ('보낼게요', 'Verb')]

# %%
import json
import os
from pprint import pprint

def tokenize(doc):
    # norm은 정규화, stem은 근어로 표시하기를 나타냄
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]

if os.path.isfile('train_docs.json'):
    with open('train_docs.json', encoding="utf-8") as f:
        train_docs = json.load(f)
    with open('test_docs.json', encoding="utf-8") as f:
        test_docs = json.load(f)
else:
    train_docs = [(tokenize(row[1]), row[2]) for row in train_data]
    test_docs = [(tokenize(row[1]), row[2]) for row in test_data]
    # JSON 파일로 저장
    with open('train_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(train_docs, make_file, ensure_ascii=False, indent="\t")
    with open('test_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(test_docs, make_file, ensure_ascii=False, indent="\t")

# 예쁘게(?) 출력하기 위해서 pprint 라이브러리 사용
pprint(train_docs[0])
# Out:
# [['아/Exclamation',
#   '더빙/Noun',
#   '../Punctuation',
#   '진짜/Noun',
#   '짜증나다/Adjective',
#   '목소리/Noun'],
#  '0']

# %%
tokens = [t for d in train_docs for t in d[0]]
print(len(tokens))
# Out:
# 2159921

# %%
import nltk
text = nltk.Text(tokens, name='NMSC')

# 전체 토큰의 개수
print(len(text.tokens))

# 중복을 제외한 토큰의 개수
print(len(set(text.tokens)))            

# 출현 빈도가 높은 상위 토큰 10개
pprint(text.vocab().most_common(10))
# Out:
# 2159921
# 49895
# [('./Punctuation', 67778),
#  ('영화/Noun', 50818),
#  ('하다/Verb', 41209),
#  ('이/Josa', 38540),
#  ('보다/Verb', 38538),
#  ('의/Josa', 30188),
#  ('../Punctuation', 29055),
#  ('가/Josa', 26627),
#  ('에/Josa', 26468),
#  ('을/Josa', 23118)]

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
# %matplotlib inline

font_fname = 'C:/Windows/Fonts/HMKMRHD.TTF'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

plt.figure(figsize=(20,10))
text.plot(50)

# %%
# 시간이 꽤 걸립니다! 시간을 절약하고 싶으면 most_common의 매개변수를 줄여보세요.

selected_words = [f[0] for f in text.vocab().most_common(100)]

def term_frequency(doc):
    return [doc.count(word) for word in selected_words]
    sleep(0.01)

train_x = [term_frequency(d) for d, _ in train_docs]
test_x = [term_frequency(d) for d, _ in test_docs]
train_y = [c for _, c in train_docs]
test_y = [c for _, c in test_docs]

# %%
import numpy as np

x_train = np.asarray(train_x).astype('float32')
x_test = np.asarray(test_x).astype('float32')

y_train = np.asarray(train_y).astype('float32')
y_test = np.asarray(test_y).astype('float32')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_code(self, code_obj, result)
#    2861                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2862                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2863             finally:
#
# <ipython-input-13-24e5c57b5b0c> in <module>()
#       2
# ----> 3 x_train = np.asarray(train_x).astype('float32')
#       4 x_test = np.asarray(test_x).astype('float32')
#
# D:\anaconda\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ...

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(3500,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

model.fit(x_train, y_train, epochs=10, batch_size=512)
results = model.evaluate(x_test, y_test)
#from keras.models import load_model
#model.save('mnist_mlp_model.h5')
# Out:
# Epoch 1/10
# 150000/150000 [==============================] - 2054s 14ms/step - loss: 0.3963 - binary_accuracy: 0.8270
# Epoch 2/10
# 150000/150000 [==============================] - 401s 3ms/step - loss: 0.3347 - binary_accuracy: 0.8534
# Epoch 3/10
# 150000/150000 [==============================] - 9s 57us/step - loss: 0.3151 - binary_accuracy: 0.8645
# Epoch 4/10
# 150000/150000 [==============================] - 7s 47us/step - loss: 0.2997 - binary_accuracy: 0.8741
# Epoch 5/10
# 150000/150000 [==============================] - 7s 45us/step - loss: 0.2842 - binary_accuracy: 0.8829
# Epoch 6/10
# 150000/150000 [==============================] - 6s 39us/step - loss: 0.2690 - binary_accuracy: 0.8903
# Epoch 7/10
# 150000/150000 [==============================] - 5s 33us/step - loss: 0.2539 - binary_accuracy: 0.8973
# Epoch 8/10
# 150000/150000 [==============================] - 5s 34us/step - loss: 0.2384 - binary_accuracy: 0.9041
# Epoch 9/10
# ...

# %%
results
# Out:
# [0.38695946771621703, 0.84633999999999998]

# %%
from tensorflow.keras.models import load_model
model.save('mnist_mlp_model.h5')

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

from tensorflow.keras.models import load_model
model = load_model('mnist_mlp_model.h5')

model

# %%
def predict_pos_neg(review):
    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        print("[{}]는 {:.2f}% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^\n".format(review, score * 100))
    else:
        print("[{}]는 {:.2f}% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;\n".format(review, (1 - score) * 100))

# %%
from konlpy.tag import Okt
okt = Okt()
def tokenize(doc):
#     # norm은 정규화, stem은 근어로 표시하기를 나타냄
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]
#selected_words = [f[0] for f in text.vocab().most_common(1000)]
#def term_frequency(doc):
#    return [doc.count(word) for word in selected_words]

train_x = model.x_train
test_x = model.x_test
train_y = model.y_train
test_y = model.y_test

predict_pos_neg("올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.")
predict_pos_neg("배경 음악이 영화의 분위기랑 너무 안 맞았습니다. 몰입에 방해가 됩니다.")
predict_pos_neg("주연 배우가 신인인데 연기를 진짜 잘 하네요. 몰입감 ㅎㄷㄷ")
predict_pos_neg("믿고 보는 감독이지만 이번에는 아니네요")
predict_pos_neg("주연배우 때문에 봤어요")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-87c36a52a73c> in <module>()
#      11 model = load_model('mnist_mlp_model.h5')
#      12
# ---> 13 train_x = model.x_train
#      14 test_x = model.x_test
#      15 train_y = model.y_train
#
# AttributeError: 'Sequential' object has no attribute 'x_train'

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %matplotlib inline

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# Using TensorFlow backend.
